# %% [markdown]
# <a href="https://colab.research.google.com/github/sitthatkaja/statistics/blob/main/Testofpaper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive # เชื่อม google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Testpaper/FON.csv')
df1
# Out:
#      Storage (af)  Inflow** (cfs)  Total Release (cfs) Unnamed: 3 Unnamed: 4  \
# 0       306040.33            7538                 6500
# 1       308168.31            7617                 6500
# 2       309767.53            7350                 6500
# 3       309919.98            6621                 6500
# 4       308472.71            5814                 6500
# ..            ...             ...                  ...        ...        ...
# 115     280705.52             826                 1100
# 116     280119.81             826                 1100
# 117     279607.67             863                 1101
# 118     279242.05             936                 1100
# 119     278511.31             752                 1100
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0
# 1
# 2
# 3
# 4
# ..         ...        ...        ...        ...        ...
# 115
# 116
# 117
# 118
# 119
#
# [120 rows x 10 columns]

# %%
ndf1 = df1[['Storage (af)','Inflow** (cfs)','Total Release (cfs)']]
ndf1
# Out:
#      Storage (af)  Inflow** (cfs)  Total Release (cfs)
# 0       306040.33            7538                 6500
# 1       308168.31            7617                 6500
# 2       309767.53            7350                 6500
# 3       309919.98            6621                 6500
# 4       308472.71            5814                 6500
# ..            ...             ...                  ...
# 115     280705.52             826                 1100
# 116     280119.81             826                 1100
# 117     279607.67             863                 1101
# 118     279242.05             936                 1100
# 119     278511.31             752                 1100
#
# [120 rows x 3 columns]

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Testpaper/CRY.csv')
df2
# Out:
#      Storage (af)  Inflow** (cfs)  Total Release (cfs) Unnamed: 3 Unnamed: 4  \
# 0        16515.52            2171                 2001
# 1        16623.32            2056                 2000
# 2        16693.43            2037                 2001
# 3        16734.40            2023                 2001
# 4        16292.31            1779                 2001
# ..            ...             ...                  ...        ...        ...
# 115      16454.49            1082                 1047
# 116      16315.43             979                 1048
# 117      16448.68            1115                 1047
# 118      16434.17            1040                 1047
# 119      16295.20            1051                 1121
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0
# 1
# 2
# 3
# 4
# ..         ...        ...        ...        ...        ...
# 115
# 116
# 117
# 118
# 119
#
# [120 rows x 10 columns]

# %%
ndf2 = df2[['Storage (af)','Inflow** (cfs)','Total Release (cfs)']]
ndf2
# Out:
#      Storage (af)  Inflow** (cfs)  Total Release (cfs)
# 0        16515.52            2171                 2001
# 1        16623.32            2056                 2000
# 2        16693.43            2037                 2001
# 3        16734.40            2023                 2001
# 4        16292.31            1779                 2001
# ..            ...             ...                  ...
# 115      16454.49            1082                 1047
# 116      16315.43             979                 1048
# 117      16448.68            1115                 1047
# 118      16434.17            1040                 1047
# 119      16295.20            1051                 1121
#
# [120 rows x 3 columns]

# %%
df3 = pd.read_csv('/content/drive/MyDrive/Testpaper/LEM.csv')
df3
# Out:
#      Storage (af)  Inflow** (cfs)  Total Release (cfs) Unnamed: 3 Unnamed: 4  \
# 0        38494.40             337                  264
# 1        38659.87             350                  264
# 2        38856.45             368                  266
# 3        38973.39             384                  323
# 4        39133.71             439                  356
# ..            ...             ...                  ...        ...        ...
# 115      15714.59              21                   13
# 116      15725.55              19                   13
# 117      15736.52              19                   13
# 118      15747.50              19                   13
# 119      15754.82              17                   13
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0
# 1
# 2
# 3
# 4
# ..         ...        ...        ...        ...        ...
# 115
# 116
# 117
# 118
# 119
#
# [120 rows x 10 columns]

# %%
ndf3 = df3[['Storage (af)','Inflow** (cfs)','Total Release (cfs)']]
ndf3
# Out:
#      Storage (af)  Inflow** (cfs)  Total Release (cfs)
# 0        38494.40             337                  264
# 1        38659.87             350                  264
# 2        38856.45             368                  266
# 3        38973.39             384                  323
# 4        39133.71             439                  356
# ..            ...             ...                  ...
# 115      15714.59              21                   13
# 116      15725.55              19                   13
# 117      15736.52              19                   13
# 118      15747.50              19                   13
# 119      15754.82              17                   13
#
# [120 rows x 3 columns]

# %%
df4 = pd.read_csv('/content/drive/MyDrive/Testpaper/ROC.csv')
df4
# Out:
#      Storage (af)  Inflow** (cfs)  Total Release (cfs) Unnamed: 3 Unnamed: 4  \
# 0        62252.24             541                  389
# 1        62176.02             391                  425
# 2        61958.53             254                  359
# 3        61817.38             241                  308
# 4        61915.08             380                  327
# ..            ...             ...                  ...        ...        ...
# 115      48128.62             179                  198
# 116      48100.35             185                  199
# 117      48034.42             164                  197
# 118      48006.18             187                  201
# 119      47968.54             186                  204
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0
# 1
# 2
# 3
# 4
# ..         ...        ...        ...        ...        ...
# 115
# 116
# 117
# 118
# 119
#
# [120 rows x 10 columns]

# %%
ndf4 = df4[['Storage (af)','Inflow** (cfs)','Total Release (cfs)']]
ndf4
# Out:
#      Storage (af)  Inflow** (cfs)  Total Release (cfs)
# 0        62252.24             541                  389
# 1        62176.02             391                  425
# 2        61958.53             254                  359
# 3        61817.38             241                  308
# 4        61915.08             380                  327
# ..            ...             ...                  ...
# 115      48128.62             179                  198
# 116      48100.35             185                  199
# 117      48034.42             164                  197
# 118      48006.18             187                  201
# 119      47968.54             186                  204
#
# [120 rows x 3 columns]

# %%
df5 = pd.read_csv('/content/drive/MyDrive/Testpaper/USR.csv')
df5
# Out:
#      Storage (af)  Inflow** (cfs)  Total Release (cfs) Unnamed: 3 Unnamed: 4  \
# 0        31530.07            1511                 1337
# 1        31511.13            1188                 1013
# 2        31511.13            1075                  855
# 3        31520.59            1180                  920
# 4        31567.97            1531                 1252
# ..            ...             ...                  ...        ...        ...
# 115      30747.05              80                   93
# 116      30706.67              73                   92
# 117      30669.41              75                   92
# 118      30715.99              77                   53
# 119      30809.23              78                   30
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0
# 1
# 2
# 3
# 4
# ..         ...        ...        ...        ...        ...
# 115
# 116
# 117
# 118
# 119
#
# [120 rows x 10 columns]

# %%
ndf5 = df5[['Storage (af)','Inflow** (cfs)','Total Release (cfs)']]
ndf5
# Out:
#      Storage (af)  Inflow** (cfs)  Total Release (cfs)
# 0        31530.07            1511                 1337
# 1        31511.13            1188                 1013
# 2        31511.13            1075                  855
# 3        31520.59            1180                  920
# 4        31567.97            1531                 1252
# ..            ...             ...                  ...
# 115      30747.05              80                   93
# 116      30706.67              73                   92
# 117      30669.41              75                   92
# 118      30715.99              77                   53
# 119      30809.23              78                   30
#
# [120 rows x 3 columns]

# %% [markdown]
# ----

# %% [markdown]
# Pre-processing

# %%
ndf1.isnull().any()
# Out:
# Storage (af)           False
# Inflow** (cfs)         False
# Total Release (cfs)    False
# dtype: bool

# %%
ndf2.isnull().any()
# Out:
# Storage (af)           False
# Inflow** (cfs)         False
# Total Release (cfs)    False
# dtype: bool

# %%
ndf3.isnull().any()
# Out:
# Storage (af)           False
# Inflow** (cfs)         False
# Total Release (cfs)    False
# dtype: bool

# %%
ndf4.isnull().any()
# Out:
# Storage (af)           False
# Inflow** (cfs)         False
# Total Release (cfs)    False
# dtype: bool

# %%
ndf5.isnull().any()
# Out:
# Storage (af)           False
# Inflow** (cfs)         False
# Total Release (cfs)    False
# dtype: bool

# %% [markdown]
# ---

# %% [markdown]
# Simple ml

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# 1

# %%
X1, y1 = ndf1.iloc[:,:-1], ndf1.iloc[:,-1]

X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size=0.2, random_state=42)

# %% [markdown]
# 2

# %%
X2, y2 = ndf2.iloc[:,:-1], ndf2.iloc[:,-1]

X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.2, random_state=42)

# %% [markdown]
# 3

# %%
X3, y3 = ndf3.iloc[:,:-1], ndf3.iloc[:,-1]

X_train3, X_test3, y_train3, y_test3 = train_test_split(X3, y3, test_size=0.2, random_state=42)

# %% [markdown]
# 4

# %%
X4, y4 = ndf4.iloc[:,:-1], ndf4.iloc[:,-1]

X_train4, X_test4, y_train4, y_test4 = train_test_split(X4, y4, test_size=0.2, random_state=42)

# %% [markdown]
# 5

# %%
X5, y5 = ndf5.iloc[:,:-1], ndf5.iloc[:,-1]

X_train5, X_test5, y_train5, y_test5 = train_test_split(X5, y5, test_size=0.2, random_state=42)

# %% [markdown]
# ---

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# 1

# %%
model1 = LinearRegression()
model1.fit(X_train1, y_train1)
y_pred_lnr1 = model1.predict(X_test1)

# %% [markdown]
# 2

# %%
model2 = LinearRegression()
model2.fit(X_train2, y_train2)
y_pred_lnr2 = model2.predict(X_test2)

# %% [markdown]
# 3

# %%
model3 = LinearRegression()
model3.fit(X_train3, y_train3)
y_pred_lnr3 = model3.predict(X_test3)

# %% [markdown]
# 4

# %%
model4 = LinearRegression()
model4.fit(X_train4, y_train4)
y_pred_lnr4 = model4.predict(X_test4)

# %% [markdown]
# 5

# %%
model5 = LinearRegression()
model5.fit(X_train5, y_train5)
y_pred_lnr5 = model5.predict(X_test5)

# %% [markdown]
# plot

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(X_test1['Inflow** (cfs)'], y_test1, 'ob',label='Fontenelle Res. Real value')
plt.plot(X_test1['Inflow** (cfs)'],y_pred_lnr1,'dr',label='Lnr Fontenelle Res.')
plt.xlabel("Inflow(cfs)")
plt.ylabel("Predict Total Release (cfs)")
plt.title('predict by linear Regression with Fontenelle Reservoir')
plt.legend();

# %%
plt.plot(X_test2['Inflow** (cfs)'], y_test2, 'ob',label='Crystal Res. Real value')
plt.plot(X_test2['Inflow** (cfs)'],y_pred_lnr2,'dr',label='Lnr Crystal Res.')
plt.xlabel("Inflow(cfs)")
plt.ylabel("Predict Total Release (cfs)")
plt.title('predict by linear Regression with Crystal Reservoir')
plt.legend();

# %%
plt.plot(X_test3['Inflow** (cfs)'], y_test3, 'ob',label='Lemon Res. Real value')
plt.plot(X_test3['Inflow** (cfs)'],y_pred_lnr3,'dr',label='Lnr Lemon Res.')
plt.xlabel("Inflow(cfs)")
plt.ylabel("Predict Total Release (cfs)")
plt.title('predict by linear Regression with Lemon Reservoir')
plt.legend();

# %%
plt.plot(X_test4['Inflow** (cfs)'], y_test4, 'ob',label='Rockport Res. Real value')
plt.plot(X_test4['Inflow** (cfs)'],y_pred_lnr4,'dr',label='Lnr Rockport Res.')
plt.xlabel("Inflow(cfs)")
plt.ylabel("Predict Total Release (cfs)")
plt.title('predict by linear Regression with Rockport Reservoir')
plt.legend();

# %%
plt.plot(X_test5['Inflow** (cfs)'], y_test5, 'ob',label='Upper Stillwater Res. Real value')
plt.plot(X_test5['Inflow** (cfs)'],y_pred_lnr5,'dr',label='Lnr Upper Stillwater Res.')
plt.xlabel("Inflow(cfs)")
plt.ylabel("Predict Total Release (cfs)")
plt.title('predict by linear Regression with Upper Stillwater Reservoir')
plt.legend();

# %% [markdown]
# ---

# %% [markdown]
# KNN Regression

# %%
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# 1

# %%
knn_model1 = KNeighborsRegressor(n_neighbors=3)
knn_model1.fit(X_train1, y_train1)
y_pred_knn1 = knn_model1.predict(X_test1)

# %% [markdown]
# 2

# %%
knn_model2 = KNeighborsRegressor(n_neighbors=3)
knn_model2.fit(X_train2, y_train2)
y_pred_knn2 = knn_model2.predict(X_test2)

# %% [markdown]
# 3

# %%
knn_model3 = KNeighborsRegressor(n_neighbors=3)
knn_model3.fit(X_train3, y_train3)
y_pred_knn3 = knn_model3.predict(X_test3)

# %% [markdown]
# 4

# %%
knn_model4 = KNeighborsRegressor(n_neighbors=3)
knn_model4.fit(X_train4, y_train4)
y_pred_knn4 = knn_model4.predict(X_test4)

# %% [markdown]
# 5

# %%
knn_model5 = KNeighborsRegressor(n_neighbors=3)
knn_model5.fit(X_train5, y_train5)
y_pred_knn5 = knn_model5.predict(X_test5)

# %% [markdown]
# plot

# %%
plt.plot(X_test1['Inflow** (cfs)'], y_test1, 'ob',label='Fontenelle Res. Real value')
plt.plot(X_test1['Inflow** (cfs)'],y_pred_knn1,'dy',label='knn Fontenelle Res.')
plt.xlabel("Inflow(cfs)")
plt.ylabel("Predict Total Release (cfs)")
plt.title('predict by K-Nearest neighbors Regression with Fontenelle Reservoir')
plt.legend();

# %%
plt.plot(X_test2['Inflow** (cfs)'], y_test2, 'ob',label='Crystal Res. Real value')
plt.plot(X_test2['Inflow** (cfs)'],y_pred_knn2,'dy',label='knn Crystal Res.')
plt.xlabel("Inflow(cfs)")
plt.ylabel("Predict Total Release (cfs)")
plt.title('predict by K-Nearest neighbors Regression with Crystal Reservoir')
plt.legend();

# %%
plt.plot(X_test3['Inflow** (cfs)'], y_test3, 'ob',label='Lemon Res. Real value')
plt.plot(X_test3['Inflow** (cfs)'],y_pred_knn3,'dy',label='knn Lemon Res.')
plt.xlabel("Inflow(cfs)")
plt.ylabel("Predict Total Release (cfs)")
plt.title('predict by K-Nearest neighbors Regression with Lemon Reservoir')
plt.legend();

# %%
plt.plot(X_test4['Inflow** (cfs)'], y_test4, 'ob',label='Rockport Res. Real value')
plt.plot(X_test4['Inflow** (cfs)'],y_pred_knn4,'dy',label='knn Rockport Res.')
plt.xlabel("Inflow(cfs)")
plt.ylabel("Predict Total Release (cfs)")
plt.title('predict by K-Nearest neighbors Regression with Rockport Reservoir')
plt.legend();

# %%
plt.plot(X_test5['Inflow** (cfs)'], y_test5, 'ob',label='Upper Stillwater Res. Real value')
plt.plot(X_test5['Inflow** (cfs)'],y_pred_knn5,'dy',label='knn Upper Stillwater Res.')
plt.xlabel("Inflow(cfs)")
plt.ylabel("Predict Total Release (cfs)")
plt.title('predict by K-Nearest neighbors Regression with Upper Stillwater Reservoir')
plt.legend();

# %% [markdown]
# ---

# %% [markdown]
# CART

# %%
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# 1

# %%
reg1 = DecisionTreeRegressor()
reg1.fit(X_train1, y_train1)
y_pred_reg1 = reg1.predict(X_test1)

# %% [markdown]
# 2

# %%
reg2 = DecisionTreeRegressor()
reg2.fit(X_train2, y_train2)
y_pred_reg2 = reg2.predict(X_test2)

# %% [markdown]
# 3

# %%
reg3 = DecisionTreeRegressor()
reg3.fit(X_train3, y_train3)
y_pred_reg3 = reg3.predict(X_test3)

# %% [markdown]
# 4

# %%
reg4 = DecisionTreeRegressor()
reg4.fit(X_train4, y_train4)
y_pred_reg4 = reg4.predict(X_test4)

# %% [markdown]
# 5

# %%
reg5 = DecisionTreeRegressor()
reg5.fit(X_train5, y_train5)
y_pred_reg5 = reg5.predict(X_test5)

# %% [markdown]
# plot

# %%
plt.plot(X_test1['Inflow** (cfs)'], y_test1, 'ob',label='Fontenelle Res. Real value')
plt.plot(X_test1['Inflow** (cfs)'],y_pred_reg1,'dg',label='CART Fontenelle Res.')
plt.xlabel("Inflow(cfs)")
plt.ylabel("Predict Total Release (cfs)")
plt.title('predict by CART with Fontenelle Reservoir')
plt.legend();

# %%
plt.plot(X_test2['Inflow** (cfs)'], y_test2, 'ob',label='Crystal Res. Real value')
plt.plot(X_test2['Inflow** (cfs)'],y_pred_reg2,'dg',label='CART Crystal Res.')
plt.xlabel("Inflow(cfs)")
plt.ylabel("Predict Total Release (cfs)")
plt.title('predict by CART with Crystal Reservoir')
plt.legend();

# %%
plt.plot(X_test3['Inflow** (cfs)'], y_test3, 'ob',label='Lemon Res. Real value')
plt.plot(X_test3['Inflow** (cfs)'],y_pred_reg3,'dg',label='CART Lemon Res.')
plt.xlabel("Inflow(cfs)")
plt.ylabel("Predict Total Release (cfs)")
plt.title('predict by CART with Lemon Reservoir')
plt.legend();

# %%
plt.plot(X_test4['Inflow** (cfs)'], y_test4, 'ob',label='Rockport Res. Real value')
plt.plot(X_test4['Inflow** (cfs)'],y_pred_reg4,'dg',label='CART Rockport Res.')
plt.xlabel("Inflow(cfs)")
plt.ylabel("Predict Total Release (cfs)")
plt.title('predict by CART with Rockport Reservoir')
plt.legend();

# %%
plt.plot(X_test5['Inflow** (cfs)'], y_test5, 'ob',label='Upper Stillwater Res. Real value')
plt.plot(X_test5['Inflow** (cfs)'],y_pred_reg5,'dg',label='CART Upper Stillwater Res.')
plt.xlabel("Inflow(cfs)")
plt.ylabel("Predict Total Release (cfs)")
plt.title('predict by CART with Upper Stillwater Reservoir')
plt.legend();

# %% [markdown]
# ---

# %% [markdown]
# support vector regression (SVR)

# %%
from sklearn.svm import SVR

# %% [markdown]
# 1

# %%
svr1 = SVR(kernel='linear', C=1.0)
svr1.fit(X_train1, y_train1)
y_pred_svr1 = svr1.predict(X_test1)

# %% [markdown]
# 2

# %%
svr2 = SVR(kernel='linear', C=1.0)
svr2.fit(X_train2, y_train2)
y_pred_svr2 = svr2.predict(X_test2)

# %% [markdown]
# 3

# %%
svr3 = SVR(kernel='linear', C=1.0)
svr3.fit(X_train3, y_train3)
y_pred_svr3 = svr3.predict(X_test3)

# %% [markdown]
# 4

# %%
svr4 = SVR(kernel='linear', C=1.0)
svr4.fit(X_train4, y_train4)
y_pred_svr4 = svr4.predict(X_test4)

# %% [markdown]
# 5

# %%
svr5 = SVR(kernel='linear', C=1.0)
svr5.fit(X_train5, y_train5)
y_pred_svr5 = svr5.predict(X_test5)

# %% [markdown]
# plot

# %%
plt.plot(X_test1['Inflow** (cfs)'], y_test1, 'ob',label='Fontenelle Res. Real value')
plt.plot(X_test1['Inflow** (cfs)'],y_pred_svr1,'dg',label='SVR Fontenelle Res.')
plt.xlabel("Inflow(cfs)")
plt.ylabel("Predict Total Release (cfs)")
plt.title('predict by support vector regression with Fontenelle Reservoir')
plt.legend();

# %%
plt.plot(X_test2['Inflow** (cfs)'], y_test2, 'ob',label='Crystal Res. Real value')
plt.plot(X_test2['Inflow** (cfs)'],y_pred_svr2,'dg',label='SVR Crystal Res.')
plt.xlabel("Inflow(cfs)")
plt.ylabel("Predict Total Release (cfs)")
plt.title('predict by support vector regression with Crystal Reservoir')
plt.legend();

# %%
plt.plot(X_test3['Inflow** (cfs)'], y_test3, 'ob',label='Lemon Res. Real value')
plt.plot(X_test3['Inflow** (cfs)'],y_pred_svr3,'dg',label='SVR Lemon Res.')
plt.xlabel("Inflow(cfs)")
plt.ylabel("Predict Total Release (cfs)")
plt.title('predict by support vector regression with Lemon Reservoir')
plt.legend();

# %%
plt.plot(X_test4['Inflow** (cfs)'], y_test4, 'ob',label='Rockport Res. Real value')
plt.plot(X_test4['Inflow** (cfs)'],y_pred_svr4,'dg',label='SVR Rockport Res.')
plt.xlabel("Inflow(cfs)")
plt.ylabel("Predict Total Release (cfs)")
plt.title('predict by support vector regression with Rockport Reservoir')
plt.legend();

# %%
plt.plot(X_test5['Inflow** (cfs)'], y_test5, 'ob',label='Upper Stillwater Res. Real value')
plt.plot(X_test5['Inflow** (cfs)'],y_pred_svr5,'dg',label='SVR Upper Stillwater Res.')
plt.xlabel("Inflow(cfs)")
plt.ylabel("Predict Total Release (cfs)")
plt.title('predict by support vector regression with Upper Stillwater Reservoir')
plt.legend();

# %% [markdown]
# ---

# %% [markdown]
# correlation

# %%
from scipy.stats import pearsonr

# %%
corr_lnr_1 = pearsonr(y_test1, y_pred_lnr1)
corr_lnr_2 = pearsonr(y_test2, y_pred_lnr2)
corr_lnr_3 = pearsonr(y_test3, y_pred_lnr3)
corr_lnr_4 = pearsonr(y_test4, y_pred_lnr4)
corr_lnr_5 = pearsonr(y_test5, y_pred_lnr5)

# %%
corr_knn_1 = pearsonr(y_test1, y_pred_knn1)
corr_knn_2 = pearsonr(y_test2, y_pred_knn2)
corr_knn_3 = pearsonr(y_test3, y_pred_knn3)
corr_knn_4 = pearsonr(y_test4, y_pred_knn4)
corr_knn_5 = pearsonr(y_test5, y_pred_knn5)

# %%
corr_crt_1 = pearsonr(y_test1, y_pred_reg1)
corr_crt_2 = pearsonr(y_test2, y_pred_reg2)
corr_crt_3 = pearsonr(y_test3, y_pred_reg3)
corr_crt_4 = pearsonr(y_test4, y_pred_reg4)
corr_crt_5 = pearsonr(y_test5, y_pred_reg5)

# %%
corr_svr_1 = pearsonr(y_test1, y_pred_svr1)
corr_svr_2 = pearsonr(y_test2, y_pred_svr2)
corr_svr_3 = pearsonr(y_test3, y_pred_svr3)
corr_svr_4 = pearsonr(y_test4, y_pred_svr4)
corr_svr_5 = pearsonr(y_test5, y_pred_svr5)

# %% [markdown]
# Eyeball Correlation

# %%
corr_lnr_1
# Out:
# PearsonRResult(statistic=0.9676614791857705, pvalue=1.2001231037434287e-14)

# %%
corr_lnr_1[0]
# Out:
# 0.9676614791857705

# %% [markdown]
# Create variable

# %%
cl1 = corr_lnr_1[0]
cl2 = corr_lnr_2[0]
cl3 = corr_lnr_3[0]
cl4 = corr_lnr_4[0]
cl5 = corr_lnr_5[0]

# %%
ck1 = corr_knn_1[0]
ck2 = corr_knn_2[0]
ck3 = corr_knn_3[0]
ck4 = corr_knn_4[0]
ck5 = corr_knn_5[0]

# %%
cc1 = corr_crt_1[0]
cc2 = corr_crt_2[0]
cc3 = corr_crt_3[0]
cc4 = corr_crt_4[0]
cc5 = corr_crt_5[0]

# %%
cs1 = corr_svr_1[0]
cs2 = corr_svr_2[0]
cs3 = corr_svr_3[0]
cs4 = corr_svr_4[0]
cs5 = corr_svr_5[0]

# %% [markdown]
# Create Dataframe

# %%
labels_cor = ['Reservoir','Cor_lnr','Cor_knn','Cor_crt','Cor_svr']
Cor_data1 = [['Fontenelle',cl1,ck1,cc1,cs1]]
Cor_data2 = [['Crystal',cl2,ck2,cc2,cs2]]
Cor_data3 = [['Lemon',cl3,ck3,cc3,cs3]]
Cor_data4 = [['Rockport',cl4,ck4,cc4,cs4]]
Cor_data5 = [['Upper Stillwater',cl5,ck5,cc5,cs5]]

df_cor_1 = pd.DataFrame.from_records(Cor_data1,columns=labels_cor)
df_cor_2 = pd.DataFrame.from_records(Cor_data2,columns=labels_cor)
df_cor_3 = pd.DataFrame.from_records(Cor_data3,columns=labels_cor)
df_cor_4 = pd.DataFrame.from_records(Cor_data4,columns=labels_cor)
df_cor_5 = pd.DataFrame.from_records(Cor_data5,columns=labels_cor)

# %% [markdown]
# RMSE (Root Mean Squared Error)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
rmse_lnr_1 = np.sqrt(mean_squared_error(y_test1,y_pred_lnr1))
rmse_lnr_2 = np.sqrt(mean_squared_error(y_test2,y_pred_lnr2))
rmse_lnr_3 = np.sqrt(mean_squared_error(y_test3,y_pred_lnr3))
rmse_lnr_4 = np.sqrt(mean_squared_error(y_test4,y_pred_lnr4))
rmse_lnr_5 = np.sqrt(mean_squared_error(y_test5,y_pred_lnr5))

# %%
rmse_knn_1 = np.sqrt(mean_squared_error(y_test1,y_pred_knn1))
rmse_knn_2 = np.sqrt(mean_squared_error(y_test2,y_pred_knn2))
rmse_knn_3 = np.sqrt(mean_squared_error(y_test3,y_pred_knn3))
rmse_knn_4 = np.sqrt(mean_squared_error(y_test4,y_pred_knn4))
rmse_knn_5 = np.sqrt(mean_squared_error(y_test5,y_pred_knn5))

# %%
rmse_crt_1 = np.sqrt(mean_squared_error(y_test1,y_pred_reg1))
rmse_crt_2 = np.sqrt(mean_squared_error(y_test2,y_pred_reg2))
rmse_crt_3 = np.sqrt(mean_squared_error(y_test3,y_pred_reg3))
rmse_crt_4 = np.sqrt(mean_squared_error(y_test4,y_pred_reg4))
rmse_crt_5 = np.sqrt(mean_squared_error(y_test5,y_pred_reg5))

# %%
rmse_svr_1 = np.sqrt(mean_squared_error(y_test1,y_pred_svr1))
rmse_svr_2 = np.sqrt(mean_squared_error(y_test2,y_pred_svr2))
rmse_svr_3 = np.sqrt(mean_squared_error(y_test3,y_pred_svr3))
rmse_svr_4 = np.sqrt(mean_squared_error(y_test4,y_pred_svr4))
rmse_svr_5 = np.sqrt(mean_squared_error(y_test5,y_pred_svr5))

# %% [markdown]
# NSE (Nash-Sutcliffe Efficiency)

# %%
nse_lnr_1 = 1 - (sum((y_test1 - y_pred_lnr1) ** 2) / sum((y_test1 - np.mean(y_test1)) ** 2))
nse_lnr_2 = 1 - (sum((y_test2 - y_pred_lnr2) ** 2) / sum((y_test2 - np.mean(y_test2)) ** 2))
nse_lnr_3 = 1 - (sum((y_test3 - y_pred_lnr3) ** 2) / sum((y_test3 - np.mean(y_test3)) ** 2))
nse_lnr_4 = 1 - (sum((y_test4 - y_pred_lnr4) ** 2) / sum((y_test4 - np.mean(y_test4)) ** 2))
nse_lnr_5 = 1 - (sum((y_test5 - y_pred_lnr5) ** 2) / sum((y_test5 - np.mean(y_test5)) ** 2))

# %%
nse_knn_1 = 1 - (sum((y_test1 - y_pred_knn1) ** 2) / sum((y_test1 - np.mean(y_test1)) ** 2))
nse_knn_2 = 1 - (sum((y_test2 - y_pred_knn2) ** 2) / sum((y_test2 - np.mean(y_test2)) ** 2))
nse_knn_3 = 1 - (sum((y_test3 - y_pred_knn3) ** 2) / sum((y_test3 - np.mean(y_test3)) ** 2))
nse_knn_4 = 1 - (sum((y_test4 - y_pred_knn4) ** 2) / sum((y_test4 - np.mean(y_test4)) ** 2))
nse_knn_5 = 1 - (sum((y_test5 - y_pred_knn5) ** 2) / sum((y_test5 - np.mean(y_test5)) ** 2))

# %%
nse_crt_1 = 1 - (sum((y_test1 - y_pred_reg1) ** 2) / sum((y_test1 - np.mean(y_test1)) ** 2))
nse_crt_2 = 1 - (sum((y_test2 - y_pred_reg2) ** 2) / sum((y_test2 - np.mean(y_test2)) ** 2))
nse_crt_3 = 1 - (sum((y_test3 - y_pred_reg3) ** 2) / sum((y_test3 - np.mean(y_test3)) ** 2))
nse_crt_4 = 1 - (sum((y_test4 - y_pred_reg4) ** 2) / sum((y_test4 - np.mean(y_test4)) ** 2))
nse_crt_5 = 1 - (sum((y_test5 - y_pred_reg5) ** 2) / sum((y_test5 - np.mean(y_test5)) ** 2))

# %%
nse_svr_1 = 1 - (sum((y_test1 - y_pred_svr1) ** 2) / sum((y_test1 - np.mean(y_test1)) ** 2))
nse_svr_2 = 1 - (sum((y_test2 - y_pred_svr2) ** 2) / sum((y_test2 - np.mean(y_test2)) ** 2))
nse_svr_3 = 1 - (sum((y_test3 - y_pred_svr3) ** 2) / sum((y_test3 - np.mean(y_test3)) ** 2))
nse_svr_4 = 1 - (sum((y_test4 - y_pred_svr4) ** 2) / sum((y_test4 - np.mean(y_test4)) ** 2))
nse_svr_5 = 1 - (sum((y_test5 - y_pred_svr5) ** 2) / sum((y_test5 - np.mean(y_test5)) ** 2))

# %% [markdown]
# RSR (Root Mean Square Ratio)

# %%
rsr_lnr_1 = rmse_lnr_1 / np.std(y_test1)
rsr_lnr_2 = rmse_lnr_2 / np.std(y_test2)
rsr_lnr_3 = rmse_lnr_3 / np.std(y_test3)
rsr_lnr_4 = rmse_lnr_4 / np.std(y_test4)
rsr_lnr_5 = rmse_lnr_5 / np.std(y_test5)

# %%
rsr_knn_1 = rmse_knn_1 / np.std(y_test1)
rsr_knn_2 = rmse_knn_2 / np.std(y_test2)
rsr_knn_3 = rmse_knn_3 / np.std(y_test3)
rsr_knn_4 = rmse_knn_4 / np.std(y_test4)
rsr_knn_5 = rmse_knn_5 / np.std(y_test5)

# %%
rsr_crt_1 = rmse_crt_1 / np.std(y_test1)
rsr_crt_2 = rmse_crt_2 / np.std(y_test2)
rsr_crt_3 = rmse_crt_3 / np.std(y_test3)
rsr_crt_4 = rmse_crt_4 / np.std(y_test4)
rsr_crt_5 = rmse_crt_5 / np.std(y_test5)

# %%
rsr_svr_1 = rmse_svr_1 / np.std(y_test1)
rsr_svr_2 = rmse_svr_2 / np.std(y_test2)
rsr_svr_3 = rmse_svr_3 / np.std(y_test3)
rsr_svr_4 = rmse_svr_4 / np.std(y_test4)
rsr_svr_5 = rmse_svr_5 / np.std(y_test5)

# %% [markdown]
# # PBIAS (Percent Bias)

# %%
pbias_lnr_1 = 100 * sum(y_test1 - y_pred_lnr1) / sum(y_test1)
pbias_lnr_2 = 100 * sum(y_test2 - y_pred_lnr2) / sum(y_test2)
pbias_lnr_3 = 100 * sum(y_test3 - y_pred_lnr3) / sum(y_test3)
pbias_lnr_4 = 100 * sum(y_test4 - y_pred_lnr4) / sum(y_test4)
pbias_lnr_5 = 100 * sum(y_test5 - y_pred_lnr5) / sum(y_test5)

# %%
pbias_knn_1 = 100 * sum(y_test1 - y_pred_knn1) / sum(y_test1)
pbias_knn_2 = 100 * sum(y_test2 - y_pred_knn2) / sum(y_test2)
pbias_knn_3 = 100 * sum(y_test3 - y_pred_knn3) / sum(y_test3)
pbias_knn_4 = 100 * sum(y_test4 - y_pred_knn4) / sum(y_test4)
pbias_knn_5 = 100 * sum(y_test5 - y_pred_knn5) / sum(y_test5)

# %%
pbias_crt_1 = 100 * sum(y_test1 - y_pred_reg1) / sum(y_test1)
pbias_crt_2 = 100 * sum(y_test2 - y_pred_reg2) / sum(y_test2)
pbias_crt_3 = 100 * sum(y_test3 - y_pred_reg3) / sum(y_test3)
pbias_crt_4 = 100 * sum(y_test4 - y_pred_reg4) / sum(y_test4)
pbias_crt_5 = 100 * sum(y_test5 - y_pred_reg5) / sum(y_test5)

# %%
pbias_svr_1 = 100 * sum(y_test1 - y_pred_svr1) / sum(y_test1)
pbias_svr_2 = 100 * sum(y_test2 - y_pred_svr2) / sum(y_test2)
pbias_svr_3 = 100 * sum(y_test3 - y_pred_svr3) / sum(y_test3)
pbias_svr_4 = 100 * sum(y_test4 - y_pred_svr4) / sum(y_test4)
pbias_svr_5 = 100 * sum(y_test5 - y_pred_svr5) / sum(y_test5)

# %% [markdown]
# ---

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.projections import polar
